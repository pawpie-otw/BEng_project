# %%
import requests as rqs
import json

# %%
available_fields = json.loads(rqs.get("http://localhost:8000/available_fields/").content)

# %%
[field["options"]
for field in available_fields['fields']]
# Out:
# [[],
#  [{'name': 'equal_weight',
#    'repr': 'Równe szanse',
#    'description': 'Każda z płci ma 50% szans na wylosowanie.',
#    'input_type': 'checkbox',
#    'return_type': 'bool',
#    'default': False,
#    'checked': False},
#   {'name': 'blanck_chance',
#    'repr': 'Szansa na brak wartości',
#    'description': 'Szansa na brak wartości przedstawiona w postaci procent.',
#    'input_type': 'range',
#    'return_type': 'int',
#    'min': 0,
#    'max': 100,
#    'default': 0,
#    'step': 1}],
#  [{'name': 'low_lim',
#    'repr': 'Dolna granica',
#    'description': 'Wiek będzie równy bądź wyższy od tej wartości.',
#    'input_type': 'range',
#    'return_type': 'int',
#    'min': 0,
#    'max': 100,
#    'default': 0,
#    'step': 1},
#   {'name': 'up_lim',
#    'repr': 'Górna granica',
#    'description': 'Wiek będzie równy bądź niższy od tej wartości.',
#    'input_type': 'range',
#    'return_type': 'int',
#    'min': 0,
#    'max': 100,
#    'default': 100,
# ...

# %%
rqs.get("http://localhost:8000/available_fields/").content
# Out:
# b'{"fields":[{"name":"id","repr":"Id","description":"Unikatowy numer wiersza.","custom_col_name":{"name":"cust_col_name","repr":"W\xc5\x82asna nazwa","description":"W\xc5\x82asna nazwa kolumny.","input_type":"text","return_type":"str","maxlength":20},"options":[]},{"name":"gender","repr":"P\xc5\x82e\xc4\x87","description":"P\xc5\x82e\xc4\x87 przedstawiona w postaci ci\xc4\x85gu znak\xc3\xb3w jako \'female\', \'male\'.\\n        ~51% szans na kobiet\xc4\x99 i ~49% szans na kobiet\xc4\x99. Szanse na wylosowanie na bazie statystyk z Polski.","custom_col_name":{"name":"cust_col_name","repr":"W\xc5\x82asna nazwa","description":"W\xc5\x82asna nazwa kolumny.","input_type":"text","return_type":"str","maxlength":20},"options":[{"name":"equal_weight","repr":"R\xc3\xb3wne szanse","description":"Ka\xc5\xbcda z p\xc5\x82ci ma 50% szans na wylosowanie.","input_type":"checkbox","return_type":"bool","default":false,"checked":false},{"name":"blanck_chance","repr":"Szansa na brak warto\xc5\x9bci","des
# ...
